A street market offers handmade crafts and unique treasures.
A pianist plays a melancholic tune in an intimate jazz bar.
A cozy cabin in the woods beckons for a quiet retreat.
A bicycle ride through a quaint village reveals charming scenery.
A telescope reveals the wonders of the night sky, planets and stars.
The aroma of freshly brewed coffee draws customers into a café.
A choir sings hymns, filling the church with melodic harmony.
A group of friends enjoys a sunset cruise on a serene lake.
A cat perches on a windowsill, observing the world with curiosity.
A gentle stream winds its way through a peaceful meadow.
The hum of cicadas provides a soundtrack to a lazy summer day.
A street painter creates a vivid mural on the side of a building.
A lone wolf howls at the moon in the quiet wilderness.
A street food vendor serves sizzling delicacies to hungry passersby.
The scent of pine and campfire smoke lingers in the air at a mountain retreat.
Friends share stories and laughter around a crackling campfire.
A bird's song greets the dawn, signaling the start of a new day.
A gentle snowfall blankets the landscape in a pristine white.
A photographer captures the vibrant colors of a bustling cityscape.
A potter molds clay into intricate shapes, creating unique ceramics.
A balloon festival fills the sky with a kaleidoscope of colors.
A lively street market offers exotic spices and international cuisine.
A solitary figure watches the sunrise from a quiet hilltop.
A guitarist strums a soothing melody by the seaside at sunset.
A train conductor calls out destinations at a bustling station.
A bee buzzes among blooming flowers, collecting nectar.
A group of friends embarks on a kayaking adventure down a tranquil river.
A juggler captivates an audience with skillful tricks in a crowded square.
A family enjoys a weekend picnic in a scenic botanical garden.
A farmer tends to rows of sunflowers swaying in the gentle breeze.
A butterfly flutters among wildflowers in a meadow.
A distant thunderstorm adds drama to the evening sky.
A jazz band improvises lively tunes at an outdoor festival.
A storyteller captivates children with enchanting tales by a campfire.
A couple dances under the fairy lights at a charming outdoor cafe.
A mountain climber conquers a challenging peak, savoring the accomplishment.
A skateboarder performs tricks in a bustling skate park.
A hot air balloon festival fills the sky with whimsical shapes.
A peaceful garden invites meditation and reflection in the heart of the city."""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
sentences = input_text.split('\n')
sentences
# Out:
# ['The sun sets behind the mountains, casting a warm glow across the valley.',
#  'Coffee beans crackle in the grinder, releasing their rich aroma.',
#  'Lost in thought, she absentmindedly twirls a strand of hair around her finger.',
#  'Neon lights flicker as the city comes alive with energy.',
#  'The old bookshop exudes a musty scent of forgotten stories.',
#  'A gentle breeze rustles the leaves, creating a symphony of nature.',
#  'Laughter echoes through the air as friends gather for a picnic.',
#  'The artist carefully dips the brush into vibrant hues, bringing the canvas to life.',
#  'Waves crash against the shore, leaving behind a trail of foamy bubbles.',
#  'Street performers captivate passersby with their mesmerizing talents.',
#  'The chef skillfully tosses vegetables in a sizzling wok, creating a tantalizing aroma.',
#  'Moonlight bathes the landscape in a soft, silvery glow.',
#  "Children's laughter rings out in the playground as they chase each other.",
# ...

# %%
tokenizer = Tokenizer(oov_token='<nothing>')
tokenizer.fit_on_texts(sentences)
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'a': 2,
#  'the': 3,
#  'of': 4,
#  'in': 5,
#  'on': 6,
#  'with': 7,
#  'air': 8,
#  'street': 9,
#  'sky': 10,
#  'and': 11,
#  'as': 12,
#  'friends': 13,
#  'at': 14,
#  'aroma': 15,
#  'to': 16,
#  'fills': 17,
#  'gentle': 18,
#  'through': 19,
#  'across': 20,
#  'scent': 21,
#  'creating': 22,
#  'laughter': 23,
#  'for': 24,
#  'quiet': 25,
#  'an': 26,
#  'around': 27,
#  'breeze': 28,
#  'into': 29,
#  'vibrant': 30,
#  'melody': 31,
#  'plays': 32,
#  'garden': 33,
#  'cozy': 34,
#  'group': 35,
#  'creates': 36,
#  'distant': 37,
#  'bustling': 38,
#  'lively': 39,
#  'their': 40,
#  'lost': 41,
#  'lights': 42,
#  'city': 43,
#  'stories': 44,
#  'leaves': 45,
#  'symphony': 46,
#  'gather': 47,
#  'picnic': 48,
#  'waves': 49,
#  'its': 50,
#  'jazz': 51,
#  'meadow': 52,
#  'train': 53,
#  'by': 54,
#  'flowers': 55,
#  'park': 56,
#  'colors': 57,
#  'sunset': 58,
#  'evening': 59,
#  'rain': 60,
#  'serene': 61,
#  'under': 62,
#  'market': 63,
# ...

# %%
input_sequences = []
for sentence in input_text.split('\n'):
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]
  print(tokenized_sentence)
  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

input_sequences
# Out:
# [3, 149, 150, 72, 3, 151, 152, 2, 73, 74, 20, 3, 153]
# [75, 154, 155, 5, 3, 156, 157, 40, 158, 15]
# [41, 5, 159, 160, 161, 162, 2, 163, 4, 164, 27, 165, 166]
# [167, 42, 168, 12, 3, 43, 169, 76, 7, 170]
# [3, 171, 172, 173, 2, 174, 21, 4, 175, 44]
# [2, 18, 28, 176, 3, 45, 22, 2, 46, 4, 77]
# [23, 78, 19, 3, 8, 12, 13, 47, 24, 2, 48]
# [3, 79, 80, 177, 3, 178, 29, 30, 81, 179, 3, 82, 16, 83]
# [49, 180, 84, 3, 181, 182, 72, 2, 85, 4, 183, 184]
# [9, 185, 186, 86, 7, 40, 87, 187]
# [3, 188, 189, 190, 191, 5, 2, 88, 192, 22, 2, 193, 15]
# [194, 195, 3, 89, 5, 2, 196, 197, 74]
# [198, 23, 199, 90, 5, 3, 200, 12, 91, 201, 92, 202]
# [203, 204, 6, 3, 205, 22, 2, 93, 31]
# [3, 206, 94, 95, 207, 208, 50, 209, 210, 211, 3, 10]
# [2, 96, 97, 32, 2, 98, 31, 5, 2, 99, 100, 51, 212]
# [3, 15, 4, 101, 213, 214, 102, 19, 3, 8, 215, 103, 104]
# [216, 217, 218, 105, 42, 5, 3, 25, 52]
# [106, 219, 220, 221, 222, 223, 3, 10, 7, 81, 4, 224, 11, 225]
# [2, 53, 226, 54, 50, 107, 227, 29, 3, 228]
# ...

# %%
max_len = max([len(x) for x in input_sequences])
max_len
# Out:
# 15

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded_input_sequences = pad_sequences(input_sequences,maxlen = max_len , padding = 'pre')
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   3, 149],
#        [  0,   0,   0, ...,   3, 149, 150],
#        [  0,   0,   0, ..., 149, 150,  72],
#        ...,
#        [  0,   0,   0, ...,   3, 509,   4],
#        [  0,   0,   0, ..., 509,   4,   3],
#        [  0,   0,   2, ...,   4,   3,  43]], dtype=int32)

# %%
x = padded_input_sequences[:,:-1]
y = padded_input_sequences[:,-1]
x
# Out:
# array([[  0,   0,   0, ...,   0,   0,   3],
#        [  0,   0,   0, ...,   0,   3, 149],
#        [  0,   0,   0, ...,   3, 149, 150],
#        ...,
#        [  0,   0,   0, ...,   5,   3, 509],
#        [  0,   0,   0, ...,   3, 509,   4],
#        [  0,   0,   2, ..., 509,   4,   3]], dtype=int32)

# %%
from tensorflow.keras.utils import to_categorical

# %%
y = to_categorical(y , num_classes = 510 )
y.shape
# Out:
# (1015, 510)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding , LSTM , Dense

# %%
model = Sequential()
model.add(Embedding(510,200,input_length = max_len-1))
model.add(LSTM(150))
model.add(Dense(510,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 14, 200)           102000
#
#  lstm_1 (LSTM)               (None, 150)               210600
#
#  dense_1 (Dense)             (None, 510)               77010
#
# ...
# Total params: 389610 (1.49 MB)
# Trainable params: 389610 (1.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])
model.fit(x,y,epochs = 100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 6s 110ms/step - loss: 6.0710 - accuracy: 0.0611
# Epoch 2/100
# 32/32 [==============================] - 2s 69ms/step - loss: 5.6313 - accuracy: 0.0719
# Epoch 3/100
# 32/32 [==============================] - 2s 66ms/step - loss: 5.4938 - accuracy: 0.0768
# Epoch 4/100
# 32/32 [==============================] - 0s 11ms/step - loss: 5.3413 - accuracy: 0.0926
# Epoch 5/100
# 32/32 [==============================] - 0s 15ms/step - loss: 5.1420 - accuracy: 0.0966
# Epoch 6/100
# 32/32 [==============================] - 1s 20ms/step - loss: 4.9256 - accuracy: 0.1133
# Epoch 7/100
# 32/32 [==============================] - 0s 15ms/step - loss: 4.7291 - accuracy: 0.1320
# Epoch 8/100
# 32/32 [==============================] - 1s 20ms/step - loss: 4.5258 - accuracy: 0.1596
# Epoch 9/100
# 32/32 [==============================] - 0s 10ms/step - loss: 4.3325 - accuracy: 0.1645
# Epoch 10/100
# ...

# %%
import numpy as np

# %%
text = "The scent of pine"
token_text = tokenizer.texts_to_sequences([text])[0]
padded_token_text = pad_sequences([token_text] , maxlen = 14,padding = 'pre')
np.argmax(model.predict(padded_token_text)).shape
# Out:
# 1/1 [==============================] - 0s 359ms/step
# ()

# %%
len(tokenizer.word_index)
# Out:
# 509

# %%
x.shape
# Out:
# (1015, 14)

# %%
y.shape
# Out:
# (1015, 510)

# %%
import time
text = "A group of friends"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=14, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks on
# 1/1 [==============================] - 0s 23ms/step
# A group of friends embarks on a
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks on a spontaneous
# 1/1 [==============================] - 0s 19ms/step
# A group of friends embarks on a spontaneous road
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks on a spontaneous road trip
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks on a spontaneous road trip chasing
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks on a spontaneous road trip chasing adventure
# 1/1 [==============================] - 0s 17ms/step
# A group of friends embarks on a spontaneous road trip chasing adventure adventure
# ...
